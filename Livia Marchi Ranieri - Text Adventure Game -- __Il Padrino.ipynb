# %%
"""
Created in October, 2020

Author: Livia Marchi Ranieri

Name: Il Padrino
"""

"""
    This game is coded based on the Godfather franchise (1972, 1974, 1990).
    Professor Chase Kusterer' Starter Code and Scripts served as a base and 
    inspiration for this game. 
    
    Watching the Godfather will definetly be an advantage for this game and
    will get you through a couple more phases! There is no way to "win" the 
    game, only to make it to the final shootout and get out alive.
    
    Respect if you can identify all of the sneaky references to the films ;)
    
    Next up you'll face:
    
    A Job interview;
    Meeting Corleone;
    First Assignment;
    Final Shootout.
        
    Bugs and Errors:
    Possible error when user inputs lower/upper case wrongly   

"""

##############################################################################

#Importing the needed packages
import time
import random
import sys, time
from sys import exit

## Making a typewriter style print for some of the lines to 
## contribute to the game's flow

def print_slow(str): 
    for letter in str:
        sys.stdout.write(letter)
        sys.stdout.flush()
        time.sleep(0.07)

def intro():
    print("""Narrator: Welcome, player! 
    
This game is about to take you on a ride along the world of the Italian Mafia. 
    
What’s more important? Individual success or family loyalty? 

Is a person capable of changing their character? 

Are your values going to keep you from succeeding in your *cof cof* unordinary career? 

These are some of the questions you'll face through the game before facing your

future as the next Godfather.

""") # Introducing the game for the player.
    
    
    print("""********************************************************************
    
    """) #This stop is to create a transition between the 
    ######introduction and the start of the game
    time.sleep(3)
    
    sicily()
# This is our first interaction with the player, where they will identify themselves:

################## Phase 1!
################## In this phase, you'll get to meet your partner Michael and 
################## decide if you have a future within the Mafia. 
################## It is called Sicily as an oath to the Motherland of the 
################## Corleone Family. 

def sicily():

#Defining global variable for the player's name, which will be 
#repeated throughout the game.
    global user_name
    
    print_slow(f"""
    Narrator: Alright... This is the one! 
    This is the interview that is going to work! 
    Make sure you look good, and march up to Corleone's Pizza with pride.
    Let's kill this job interview. 
    
    ******* As you arrive at the Pizza Shop... *******
    
    
    """) 

#The player was initially interviewing for a pizza shop job (or at least that's what they though!)
    
    time.sleep(2)
    
    goon_name = ['Jimmy', 'Tony', 'Gino', 'Paul'] 
    goon = random.choice(goon_name) #Adding random function to determine goon's name
    #### Start of the use of variables in the game
    
    print(f"""
    
    Michael: What are you looking at? Did {goon} send you?
    """) 
    
    print("""
    
    Michael: What's your name kid?
    """)
    user_name = input("Your name: \n").capitalize()

    while not user_name.isalpha():
        user_name = input("""Hm, I don't think that's right... Try again! Tip: Input an actual name :)""")
        if user_name.isalpha():
            break
        sicily() ### Adding a loop to make sure the player is typing their 
        ######### name/ nickname
        ####### isalpha() idea come from research here:
        #### https://careerkarma.com/blog/python-isalpha-isnumeric-isalnum/ and
        ##### here: https://stackoverflow.com/questions/22932789/alphabet-check-as-input
    
    print(f"""
    
    Michael: Ahh, so you're the new hire, {user_name}. 
    
    Listen, do you think you're ready for this job?
    
    """)
    time.sleep(2)
    print_slow(f"""
    
    Narrator: 
    
    Wait a minute.. Is that Al Pacino?

    Oh no, you are being recruited into the mafia.
    It is time to make up your mind.""")
    time.sleep(2)
    
    choice = input("""
    
    Say yes if you want to take the job and keep your head.
    
    Say no... and try your luck.""")

    choice = choice.lower() ##User the lower function so the player's 
    ####response isn't affected by lower/upper case answers

    ### Start of while loop for player's answer to be accepted 
    while True :
        
        if 'yes' in choice:
            print(f"""
            
            {user_name}: Alright. I'm in.\n""")
            chicago()
            break

        elif 'no' in choice:
            print(f"""
            
            {user_name}:  Thanks but no thanks. I'm out.\n""")
            fail()
            break
        
        else:
            print("Invalid input. Please try again!")
            choice = input("""
    
    Say yes if you want to take the job and keep your head.
    
    Say no... and try your luck.
    """)
            choice = choice.lower()

def chicago(): #### Start of the next phase, where the player will meet 
    ##### Don Corleone. The phase is called Chicago as a tribute to the
    ##### Chicago Outfit mafia. 
    
    print(f"""
    
    Michael: Good choice {user_name}! Now, you gotta go 
    
    and talk to the boss and get his blessing.
            
    Make sure you address him properly.
    """) #Using global variable to address player by name
    
    time.sleep (2)
    
    print_slow("""
    
    Narrator: You're nervous, confused..         
    You thought you were applying for a job punching down dough at 
    a pizza shop. Apparently, you'll be punching other things..""")
    
    time.sleep(2)
    
    print_slow("""
    
    Narrator: As you enter the room, you see this man in dim light. 
    This is it, you are meeting Don Corleone for your first assignment. 
    
            """)    
    time.sleep(1)
    
    #### Don Corleone image created with: https://www.ascii-art-generator.org.  
    print("""
    
                               '..,ldddkOOOKXXNNWWWNX0Oxdocll
                              ''',cdOKXXNWWWMWWWWWWNNXXKOxdo;.;O
                             :.:odxO0KXXXNNWWWWWWWWWNXXXXK0kdl;.,k
                            :':dkkO0KKKKKXXNWWWWWNNNXXKKKKXKOkc'..d
                           :';cdxkkOO000KKKXXXNNNXXXKK0000KKK0kdl:,d
                           ',;;:lodxkkkOOO000000000OOOOOOO0000Okkc'c
                           ',,',;ccldkkkkkkkkkkOOOOOOkOOOOOOOOkdo:,l0
                           ....',;:clxkkkkxxkkO00000000O0OOkxdllc;;oO
                           '....,;clodxkkkkxkkO000O00KKKKK0Oxoc'',:oO
                           '...';cooodxxkkkxolc:;;;;::cccloxxxd;.,;;o
                            ...''.','',,,;ldl'.........''..,oxxl;;clx
                            ..............:kOl'.........';;cdkkdc:lxK
                            ;.............:OKko;,''',::cdkkO0OkdddxkX
                             '.......',,,.:k0OkkkxxdddkkOOOOOxdollokK
                             ....',:cll;.:x0OkkkkOOOkkkkxddddddlcd0N
                              ,..;cloddc''lx00OkxdodkOOkxxdddxxxx0XNW
                              ,.';codoc'':oxxdllodoodkkkkxxkkxxOXWWN
                               ..';cll;....,,',:dkOkdxkkkkkkxxxkXWWN
                                '.',;::'.....,:lolllodxkkOOkkxxdkXXNW
                                  ';:;,.....;ooc:::::cdkOOOkxxdoxKN
                                 .:l:'.....';:cllooodddkkkkxdco0k
                                  ..::,...';cloddxxxkkkxddddl::OWk...,
                                   '.''',,'...'',;:coooolc:,,c0NO;.......'
                                    '....',;:lodddddoodo:'':xXWO,..............
NNWWWNNNWWWN0O0XNXkl:cxKNKl',:lodxxdc.....,::cloollllll;.'lONKo'. ..........'...........,
MMNXNNNXOk0K00KXXKXX0l,cdko,,;,;::;'... ....'',;,''''...'oOko'. .,............'............  ..
NNNX0Od:,',::lxKNXK0KKl...';ox:...  ..    .............,ll;....;Od.............'................ '
NNNx:c:'...''.':oollxKKo..':lxl. .  .     ............;c'  ....;xc............................... 
MMXc;ooc'.....';;'',cdko'..;col'...       ..,''.... .... ............'........................... ,0
NNXl,oxxl,.''';col;,:lc.....,:l,.....      .....      ......',,;;....'''................... ..... 'O
NNKc:xk00d;'''';xOc,;cddccl:,;,.......         ..',,,:odxkO00KXN0;............................... .k
MM0;:dxkOko;''..;xdccokK0kdoo:........    ....',;colldkkOkxdodkKk,............................... .k
NW0;,ldxkkxo:,'..cdddOKXK0Okd,............';:lloododdxkkOO000KXNO,............................... .k
NWK;.;cldkkkxollclodxO00Okoc;..........,codxkO000KKKXNWWWWWWWWWWK:............';:cl:'''.......... .k
MNx...,:oxkOOkxxdddddxxdo:'...........'d00KKXXNWWWWWWWMMWMMMMMMMXl............;:::lc;:cc'........ .O
Xl....,:ldxxxxdoccc:::;,..............;0NNNNWWWWMWWWWWMMMMMMWWWWNx............;:::cc;;:,......... 'O
k. ..,,;,,;;;cc;........  .......  ...:XWWWWWWWWWWWWWWWWWWWWWWWWW0,.............',;;,;'........ . .O
KolooddooodddddollccclcccclllccclllcclkNWWWWWWWWWWWWWWWWWWWWWWWWWXxlllllllllllcllooodolllccllllcccoK""")  
#### Here is an image of Don Corleone to make the game more fun and interactive!
    greeting = input("""
    1) Call him Godfather and offer your friendship.
    
    2) Call him Don Corleone to ask for justice without respect.
    
    3) Run
    
    """)
    if greeting == 'Godfather' or greeting == '1' or greeting == 'friendship': 
        first_assignment()
    #### Here I am making sure the inputs can be more than just the numbers    
    elif greeting == 'Don Corleone' or greeting == 'justice' or greeting == 'no respect' or greeting == '2':
        print_slow(f"""
        
        Don Corleone: But now you come to me and you say,
        'Don Corleone, give me Justice.'  
        But you don't ask with respect, you don't offer friendship;  
        you don't even think to call me Godfather...  
        Get outta here, {user_name}.
        
        """) #### This is a quote from the movie Godfather, establishing
        ######### Don Corleone as the big boss that must be respected 
        ######### (If you'd like to live.)
        time.sleep(1)
        
        print(f"""
        Narrator: This doesn't look good, {user_name}...
        
        """)
        time.sleep(1)
        
        fail()
    
    elif greeting == '3' or greeting == 'Run':
        fail() ### Here running would cause you to loose
    
    else:
        print("Invalid entry. Please try again.\n")
        chicago() ### If the input is invalid, phase will restart
        
################## Next phase!
################## No turning back, you're in the mafia now. 
################## Here the player will have their first task and 
################## prove their worth to Michael and the Family. 

def first_assignment():
    print_slow("""
    
    Narrator: Wooo... You made it in.
    Your mother raised you right, congrats on having manners!
    This is your first assignment. 
    Take a look at your inventory and pick what you are willing to do.""")
    
    time.sleep(2)
    print("""
    
    Michael: So, this is what we have in inventory at the moment:
    """)
    time.sleep(2) ##Start of a loop to print out list of inventory. Loop breaks after the desired items have been printed
    lst = ['Gun', 'Car','Head of a Dead Horse','Swimsuit','Mug','Broccoli'] #Using this list for the loop
    for element in lst:
        print(element)
        if element == 'Head of a Dead Horse':
            break ### Here the break is used to make sure the loops only prints the parts we want for the game
    time.sleep(1)
    inventory  = ['gun', 'car','head of a dead horse']
    print("""
    
    What will your first assignment as part of the Corleone family be?
    
            Please pick a number so we can continue: 
            
          1) Take the gun 🔫 and car and patrol the neighborhood 
          2) Call your mom and ask for help
          3) Get the head of a dead horse and leave it on the bed of your enemy""")
    
    pick = input(">  \n") ### User must input their decision in order to continue/loose the game
    
    if pick =='1' or pick =='gun' or pick == 'car' or pick == 'patrol the neighborhood' and 'gun' in inventory:
        print ("""
            
        Michael: Good! I like how you think. Get the gun and car and let's go. """)
    
        time.sleep(2)
        input("<Press enter to continue>\n")
        final_shootout() ### This choice moves player to the next phase
    
    elif pick == '2' or pick == 'call mom' or pick == 'call my mom':
        print("""
        
        Michael: What kind of person involves their mother in their mafia business?
        
        """)
        time.sleep(2)
        fail() ## This choice makes player loose
        
    elif pick == '3' or pick == 'head of a dead horse' and 'head of a dead horse' in inventory: 
        print("""
        
        Michael: Gosh, you're cold. 
        
        I guess the Corleone family can really count on you to do their 
        dirty work eh?
        
        Maybe next time kid. Let's go have a look around the neighborhood.
        
        """)
        time.sleep (2)
        input("<Press enter to continue>\n")        
        final_shootout() ## This will also move the player to the next phase, it's just funnier :)
    
    else:
        print("Invalid command. Please try again.") ### Making sure the player can move on only with valid 
        input("<Press enter to continue>\n")        #### commands.
        first_assignment()

################## Phase 3!       
################## The final shootout will determine whether you make a name for yourself or not!   
def final_shootout():
    
    print("""
    Michael: Everything seems so quiet around here..
    
    Almost too quiet...""")
    
    time.sleep(3)
    
    print("""
    ************************************ 
    ######  ####### ####### #     # ### 
    #     # #     # #     # ##   ## ### 
    #     # #     # #     # # # # # ### 
    ######  #     # #     # #  #  #  #  
    #     # #     # #     # #     #     
    #     # #     # #     # #     # ### 
    ######  ####### ####### #     # ### 
    ************************************""") #### Created with: https://www.ascii-art-generator.org.
    
    print(f"""
    Michael: Oh crap, it's the Barzinis! 
    
    They have been trying to get their status back as most powerful family
    
    by bombing our fine establishments in the neighborhood.
    
    What do we do, {user_name}?
    
    """) 
    time.sleep (2)
    
    print_slow("""
    Narrator: Oh no, PANICK MODE!
    
    Never thought the first day of work would be this crazy!
    """)
    time.sleep(2) ##Start of nested conditional 
    
    bullets = 100
    barzinis = 20
    
    print("""
    
    Michael: We should have enough bullets..
    
    Let's check.""")
    
    time.sleep(2)
    
    # Here the nested conditional makes sure that the bullets are enough for this battle
    if bullets > barzinis:
        if bullets >= (.5 * barzinis):
            print("""
            
    Michael: Gosh, it's cutting close. 
    
    There is about 20 of them.
    
    But we'll make it!""")
            
        else:
            print("""
                
                
    Michael: Damn, we need more bullets!!!!""")
    
    elif bullets == barzinis:
        print ("""
        
    Michael: Wow, I'm not sure we'll make it. 
    
    We really need to think this through.""")
        
    else: 
        print ("""
    
    Michael: Shall we try to run?""")
    
    
    possible_moves = input(f"""
    
    Michael: {user_name}! Come on, kid! Look alive! What do we do: Attack, Protect or Run?""")
    ### As we are moving closer to the end of the game, there is only 1 right answer here
    if possible_moves == 'Protect' or possible_moves == '2' or possible_moves == 'protect':
        print("""
        
        Michael: Let's try to barricade the shop!
        
        Michael: Help me move these tables closer to the window.""")
        time.sleep(2)
        
        print("""
        
        Narrator: As you're going for the table, one of the Barzinis comes 
        
        in the shop and...""")
        
        time.sleep(1)
        fail() #This makes the player fail the game
        
    elif possible_moves == 'Attack' or possible_moves == 'attack' or possible_moves == 1:
        print(f"""
        
        Michael: Alright, let's do this. 
        
        You take the right and I'll go left.
        
        
        ********** Insert shootout appropriate soundtrack here, {user_name} **********
        
        """) ### This is right choice and will move player to the epic finale!
        time.sleep(1)
        
        print_slow("""
        Narrator: After one hour, you made it.
        The Barzinis that survived ran away.
        Victory!""")
        
        time.sleep(1)
        
        print_slow("""
        
        Narrator: You feel alive. You and Michael need to celebrate!
        But, where the hell is he?""")
        
        time.sleep(1)
        
        print_slow("""
        
        Michael: *faint voice* Kid, I'm over here. 
        I've been shot. You'll need to be second in command for me...
        Tell... Tell my dog I love him.
        I'll see you on the other side.""")
        
        time.sleep(1)
        
        print_slow("""
        
        Narrator: This is crazy. 
        Guess this is it... Time for the epic finale.""")        
        finale()
        
    elif possible_moves == 'Run' or possible_moves == 'run':
            print("""
        Michael: Really, you are going to leave me alone right now?
        
        HOW DARE YOU?""")
            time.sleep(1)
            fail() ##This will make coward players loose the game :P
        
    else:
        
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n")
        final_shootout() ## If the player's input is invalid, it will simply restart and ask him again
            
def finale():
    print_slow("""
    
    Narrator: A couple of years have gone by.. 
    You are at your niece's baptism. 
    
    You are now the second in command. 
    
    Your mom thinks you're a pizza maker.. But it's better that way. 
    You know what they say: first rule of the mafia is - you don't talk about the mafia.
    
    Or wait, maybe that's a different movie.""") ### This is it! As explained, there is no "winning"
    ### in the game, only reaching the finale or not. 
    
    game_over = input(f"""
     
        {user_name}, do you want to go again? Maybe this time you'll save Michael's life...
        a) Yes
        b) No
""").lower() #Here the .lower() is used to make sure the capitalization of the answer is not important
        
    if game_over == 'yes' or game_over == 'a':
            print ("""
            
            Alright!
            """)
            intro() ### If the player wants to go again, the game will restart
            
    elif game_over == 'no' or game_over == 'b':
        are_you_sure = input("""> Are you sure?""").lower()### Here I added another nested conditional to make sure 
        ### The player REALLY does not wanna play again!
        if are_you_sure == 'yes':
            print("""
            
            No problemo! See ya later.
            """)
            time.sleep(1)
            exit() ### Imported exit() to close the game once player is done.
        elif are_you_sure == 'no':
            time.sleep(1)
            intro()
        else: 
            print("""
        
        Hm, I'm not sure I got that.. 
        
        Please try 'yes' or 'no'.""") 
        
        finale()    
    
    else:
        print("""
        
        Hm, I'm not sure I got that.. 
        
        Please try 'yes' or 'no'.""") 
        
        finale()        #### Making sure that the player inputs a valid answer.
        
def fail(): #### Defininf a fail function for the game. 
    print(f"""    
        (  _ \(  _  )( ) ( )(  _ \    (  _ \(  _  )( ) ( )(  _ \ ( )
        | (_) ) (_) ||  \| || ( (_)   | (_) ) (_) ||  \| || ( (_)| |
        |  _ ((  _  )|     || | __    |  _ ((  _  )|     || | __ | |
        | (_) ) | | || | \ || |(_ )   | (_) ) | | || | \ || |(_ )(_)
        (____/(_) (_)(() (_)(____/    (____/(_) (_)(() (_)(____/    
                     (_)                           (_)           (_)
                     
       Well, better luck next time. Or next LIFE. 
        
        Game over :(""")#### Created with: https://www.ascii-art-generator.org.
    
    input("<Press enter to play again>\n")
    intro()  ## In case the player fails, they have the option of playing again
        
intro()
# Out:
# Narrator: Welcome, player!
#
# This game is about to take you on a ride along the world of the Italian Mafia.
#
# What’s more important? Individual success or family loyalty?
#
# Is a person capable of changing their character?
#
# Are your values going to keep you from succeeding in your *cof cof* unordinary career?
#
# These are some of the questions you'll face through the game before facing your
#
# future as the next Godfather.
#
#
# ********************************************************************
#
#
#
#     Narrator: Alright... This is the one!
#     This is the interview that is going to work!
#     Make sure you look good, and march up to Corleone's Pizza with pride.
#     Let's kill this job interview.
#
#     ******* As you arrive at the Pizza Shop... *******
#
#
#
#
#     Michael: What are you looking at? Did Gino send you?
#
#
#
#     Michael: What's your name kid?
